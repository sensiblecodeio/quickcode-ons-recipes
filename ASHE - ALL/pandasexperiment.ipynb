# %%
from databaker.framework import *
import zipfile, io, re, os

# %%
from tempfile import NamedTemporaryFile

dirname = "table7zips"
dfiles = os.listdir(dirname)
dfiles.sort(reverse=True)
dfile = dfiles[0]
zfile = os.path.join(dirname, dfile)
zfile

os.path.getsize(zfile)
# Out:
# 6176784

# %%
zdir = zipfile.ZipFile(zfile)
xlsfilenames = zdir.namelist()
xlsfilename = xlsfilenames[0]
xlsfilename
# Out:
# 'PROV - Work Geography Table 7.1a   Weekly pay - Gross 2016.xls'

# %%
z = zdir.read(xlsfilename)
print(len(z))
z[:100]
# Out:
# 893440
# b'\xd0\xcf\x11\xe0\xa1\xb1\x1a\xe1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00>\x00\x03\x00\xfe\xff\t\x00\x06\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x0e\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\xc9\x06\x00\x00\x01\x00\x00\x00\xfe\xff\xff\xff\x00\x00\x00\x00\x00\x00\x00\x00g\x00\x00\x00\xe3\x00\x00\x00d\x01\x00\x00\xe5\x01\x00\x00t\x02\x00\x00'

# %%
import pandas as pd
tf = NamedTemporaryFile("w+b", suffix=".xls")
tf.write(z)
k = pd.read_excel(tf.name, sheetname=None)

# %%
k["All"]
# Out:
#     Table 7.1a   Weekly pay - Gross (£) - For all employee jobsa: United Kingdom, 2016  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                          Description
# 4                                       United Kingdom
# 5                                        Great Britain
# 6                                    England and Wales
# 7                                              England
# 8                                           North East
# 9                                        Darlington UA
# 10                                       Hartlepool UA
# 11                                    Middlesbrough UA
# 12                             Redcar and Cleveland UA
# 13                                 Stockton-on-Tees UA
# 14                                    County Durham UA
# 15                                   Northumberland UA
# 16                                    Tyne and Wear MC
# 17                                           Gateshead
# 18                                 Newcastle upon Tyne
# 19                                      North Tyneside
# 20                                      South Tyneside
# 21                                          Sunderland
# 22                                          North West
# 23                            Blackburn with Darwen UA
# 24                                        Blackpool UA
# 25                                           Halton UA
# 26                                       Warrington UA
# 27                                    Cheshire East UA
# 28                        Cheshire West and Chester UA
# 29                                             Cumbria
# ..                                                 ...
# 411                                       East Lothian
# 412                                  East Renfrewshire
# 413                                  City of Edinburgh
# 414                                        Eilean Siar
# 415                                            Falkirk
# 416                                               Fife
# 417                                       Glasgow City
# 418                                           Highland
# 419                                         Inverclyde
# 420                                         Midlothian
# 421                                              Moray
# 422                                     North Ayrshire
# 423                                  North Lanarkshire
# 424                                     Orkney Islands
# 425                                  Perth and Kinross
# 426                                       Renfrewshire
# 427                                   Scottish Borders
# 428                                   Shetland Islands
# 429                                     South Ayrshire
# 430                                  South Lanarkshire
# 431                                           Stirling
# 432                                West Dunbartonshire
# 433                                       West Lothian
# 434                                   Northern Ireland
# 435                                     Not Classified
# 436  a  Employees on adult rates whose pay for the ...
# 437  b  Figures for Number of Jobs are for indicati...
# 438  KEY - The colour coding indicates the quality ...
# 439  The quality of an estimate is measured by its ...
# 440  Source: Annual Survey of Hours and Earnings, O...
#
#     Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6  \
# 0          NaN         NaN        NaN         NaN        NaN         NaN
# 1          NaN      Number        NaN      Annual        NaN      Annual
# 2          NaN    of jobsb        NaN  percentage        NaN  percentage
# 3         Code  (thousand)     Median      change       Mean      change
# 4          NaN       25762      438.6         3.2      524.5         3.4
# 5          NaN       24930        440         3.3      526.6         3.4
# 6          NaN       22710      440.8         3.4      528.7         3.4
# 7          NaN       21613      441.9           3        532         3.4
# 8          NaN         957      403.8         2.2      466.6         0.3
# 9    E06000005          44      433.4        -0.7      471.7        -5.4
# 10   E06000001          28        420          11      444.4         0.7
# 11   E06000002          66      384.9         0.8      456.3        -0.1
# 12   E06000003          26      362.2        -3.6      419.6        -4.2
# 13   E06000004          77      407.9         4.5      463.3           2
# 14   E06000047         153        410         1.5      462.2         1.3
# 15   E06000057          77      352.3         2.2      410.6         3.4
# 16   E11000007         487      409.1         2.6      482.4         0.1
# 17   E08000037          83      398.1        -0.9      464.2        -0.2
# 18   E08000021         161      432.9         6.3      525.8         5.3
# 19   E08000022         100      404.8         2.5        460         0.5
# 20   E08000023          39      378.7        -2.8      415.9         NaN
# 21   E08000024         105      410.5         4.5      476.3         5.5
# 22         NaN        2696        414         3.6      485.2         3.5
# 23   E06000008          52      401.4         3.4      481.4         1.6
# 24   E06000009          45      333.4         2.6      422.1         1.8
# 25   E06000006          55      444.2         0.6        534        -2.7
# 26   E06000007         109      448.4         4.6      513.8         5.7
# 27   E06000049         158      431.2         7.6      512.8         8.2
# 28   E06000050         144      395.2         5.3      467.8         3.9
# 29   E10000006         189        403         5.8      475.5         4.9
# ..         ...         ...        ...         ...        ...         ...
# 411  S12000010          30      393.2         5.7      460.8         7.2
# 412  S12000011          19        345        10.2      415.6         9.3
# 413  S12000036         290      480.1        -0.1      578.2         2.1
# 414  S12000013          10      368.2       -12.3      378.7       -12.2
# 415  S12000014          54      452.9         8.1      504.8         9.2
# 416  S12000015         121      393.2         2.1      456.3           4
# 417  S12000046         353      465.9         4.1      544.8           6
# 418  S12000017          94        409         7.7      473.2         8.5
# 419  S12000018          28      362.4        -1.2      468.4         4.6
# 420  S12000019          29      475.2        17.4      503.9          11
# 421  S12000020          35      374.5         2.1      434.7        -1.5
# 422  S12000021          37      406.5         6.9      444.1         1.3
# 423  S12000044         105      433.6         5.2      497.4         5.5
# 424  S12000023           9      373.1         NaN      424.9        15.1
# 425  S12000024          64      413.1         0.2      483.3         5.1
# 426  S12000038          75      408.7        -1.6      485.3         2.2
# 427  S12000026          38      364.3        -4.6      407.3        -2.4
# 428  S12000027          12      499.9         8.1      534.7        12.9
# 429  S12000028          44      391.3         2.2      493.7         3.7
# 430  S12000029         113      447.1          10      499.1         6.4
# 431  S12000030          37      403.5        -3.2      485.1         5.4
# 432  S12000039          29      434.2        15.4      496.4          15
# 433  S12000040          87      421.5        -0.5      474.1        -2.6
# 434        NaN         832        393         2.9      461.5         4.2
# 435        NaN           :        NaN         NaN        NaN         NaN
# 436        NaN         NaN        NaN         NaN        NaN         NaN
# 437        NaN         NaN        NaN         NaN        NaN         NaN
# 438        NaN         NaN        NaN         NaN        NaN         NaN
# 439        NaN         NaN        NaN         NaN        NaN         NaN
# 440        NaN         NaN        NaN         NaN        NaN         NaN
#
#       Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0            NaN        NaN        NaN         NaN         NaN         NaN
# 1            NaN        NaN        NaN         NaN         NaN         NaN
# 2    Percentiles        NaN        NaN         NaN         NaN         NaN
# 3             10         20         25          30          40          60
# 4          141.4      231.3        276         308       371.3       516.4
# 5          141.7      232.7      277.2       309.4         373       517.5
# 6          141.7      232.8      277.4       309.5       373.5       518.3
# 7          141.6      233.1        278       310.5       374.9       521.2
# 8          136.4      223.2      264.9       293.3       346.2       471.9
# 9          178.2      268.9      300.4       325.7       367.3       492.2
# 10         117.4      199.8      226.1         263       334.2       472.4
# 11         121.4      213.8      264.1       284.7       340.1       446.3
# 12         137.3      179.7      213.4       255.5       302.8       447.6
# 13         126.7      222.1      258.2         291       344.3       490.1
# 14         136.1        240      274.6       300.8       352.4       476.2
# 15         110.6      178.7      209.3       247.5       298.9       426.7
# 16         143.5        230        270       300.8       354.5       479.9
# 17         129.1      220.7      259.8       289.3       349.5       454.6
# 18         160.8      253.6      289.5       316.8       371.4       505.2
# 19         136.6      222.7      260.1       289.7       346.4       469.7
# 20         104.8      186.4      215.9       258.2       319.3       419.2
# 21         147.9      236.8      273.6       304.8       352.9       479.1
# 22         137.9      225.1      268.3       298.2       352.2       481.2
# 23         158.2      234.1      272.2       298.2       335.4       463.7
# 24         119.8      194.2      231.2       261.6       297.2       394.5
# 25           155        248      275.3         317       387.2       508.8
# 26         148.7      253.5      289.2         328       387.6       521.9
# 27         135.6      222.7      275.3       311.6       369.8       497.1
# 28         127.6      215.4      254.1       288.5       341.9       471.2
# 29         122.4      196.8      231.4       279.1       337.1       483.8
# ..           ...        ...        ...         ...         ...         ...
# 411            x      219.7      251.5       272.4         339         468
# 412         98.4      125.3          x           x       295.7         402
# 413        166.6      288.5      325.4       355.5         417       562.1
# 414            x          x          x           x         326         429
# 415        151.3      244.9        290       321.1       367.6       513.8
# 416          140      217.5        254       287.4         332       470.3
# 417        154.3      261.7      300.1       336.2       399.6       536.6
# 418        120.2        206      242.7       274.9       342.3       480.2
# 419        122.4      200.1      218.5       232.9       306.2       465.3
# 420        173.1      245.3      292.8       327.3       403.7       543.5
# 421            x      183.8        218       259.1       316.3         427
# 422        150.8      218.8      240.5       271.7       331.3       479.3
# 423        167.5      270.2      294.9       329.6         391       497.3
# 424            x          x          x           x           x           x
# 425        137.5      228.7      273.9       301.1       357.3       474.8
# 426        148.3      224.4      271.1       304.6         358       465.1
# 427        111.3      195.6      242.5       282.9         327       435.2
# 428            x      240.3      285.7       313.2       420.7       591.2
# 429        125.2      201.2      227.2         274       335.8       481.3
# 430          142      214.3      274.4       316.4       388.5       547.1
# 431        127.9      209.7      253.5       286.8       338.7       494.5
# 432        147.1      242.9      302.7         326       386.1       474.7
# 433        169.2      257.8        290       331.8         377       484.4
# 434        132.9      210.6      243.4       276.7       332.9       462.2
# 435          NaN        NaN        NaN         NaN         NaN         NaN
# 436          NaN        NaN        NaN         NaN         NaN         NaN
# 437          NaN        NaN        NaN         NaN         NaN         NaN
# 438          NaN        NaN        NaN         NaN         NaN         NaN
# 439          NaN        NaN        NaN         NaN         NaN         NaN
# 440          NaN        NaN        NaN         NaN         NaN         NaN
#
#     Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  Unnamed: 17  \
# 0           NaN         NaN         NaN         NaN          NaN
# 1           NaN         NaN         NaN         NaN          NaN
# 2           NaN         NaN         NaN         NaN          NaN
# 3            70          75          80          90          NaN
# 4         611.5       670.8       736.8       953.4          NaN
# 5         613.3       670.8       739.3       957.6          NaN
# 6         614.1       673.2       744.1       958.2          NaN
# 7         617.5       675.1       748.8       966.7          NaN
# 8         549.2       598.2       659.9         828          NaN
# 9           559       590.6       684.9           x          NaN
# 10        540.2       582.3       630.1           x          NaN
# 11          550       624.5       678.4           x          NaN
# 12        504.4       583.6       626.5           x          NaN
# 13        555.5       617.2       670.8           x          NaN
# 14        558.2       601.3       664.7       797.5          NaN
# 15        492.3       541.9       596.3           x          NaN
# 16        554.5       602.4       667.3       875.2          NaN
# 17          541       584.5       629.4           x          NaN
# 18        595.5       668.4       756.7       975.9          NaN
# 19        545.5       574.9       636.4           x          NaN
# 20        493.4       541.2       611.3           x          NaN
# 21        546.3       593.3       630.4       822.4          NaN
# 22        573.8       625.7       689.2       870.4          NaN
# 23        529.5       562.8       628.9           x          NaN
# 24        479.1       520.1       556.3           x          NaN
# 25        622.6       701.2       773.2           x          NaN
# 26        621.7       667.2       727.3       950.6          NaN
# 27        600.7       670.8       735.1       938.6          NaN
# 28        556.8         608       673.9       860.3          NaN
# 29        592.4       645.2       713.9       897.5          NaN
# ..          ...         ...         ...         ...          ...
# 411       563.7       633.9       671.9           x          NaN
# 412       478.8       539.1           x           x          NaN
# 413       655.6       723.5       797.8      1053.9          NaN
# 414         460       480.1           x           x          NaN
# 415         584       633.8       695.1           x          NaN
# 416       566.1       606.7       674.1       792.1          NaN
# 417       625.2       678.1       726.5       922.7          NaN
# 418       557.9       598.7       651.6           x          NaN
# 419       546.6       601.5           x           x          NaN
# 420       625.4       667.3       693.1           x          NaN
# 421       519.8       598.4         679           x          NaN
# 422       542.5       587.5       626.5           x          NaN
# 423       572.3       628.7       670.5       817.7          NaN
# 424           x           x           x           x          NaN
# 425       553.7         623         686           x          NaN
# 426       561.9       595.2       670.8           x          NaN
# 427       472.9       509.7         545           x          NaN
# 428       690.9       738.4           x           x          NaN
# 429       587.2       641.1       727.6           x          NaN
# 430       613.5       650.5       697.2         856          NaN
# 431       589.1       642.1       685.4           x          NaN
# 432       557.2       613.4       651.1           x          NaN
# 433       557.5       614.4       660.1       787.2          NaN
# 434       546.2       599.3       672.5       828.2          NaN
# 435         NaN         NaN         NaN         NaN          NaN
# 436         NaN         NaN         NaN         NaN          NaN
# 437         NaN         NaN         NaN         NaN          NaN
# 438         NaN         NaN         NaN         NaN          NaN
# 439         NaN         NaN         NaN         NaN          NaN
# 440         NaN         NaN         NaN         NaN          NaN
#
#                 Unnamed: 18                                        Unnamed: 19
# 0                       NaN                                                NaN
# 1                       NaN                                                NaN
# 2                       NaN                                                NaN
# 3                       NaN                                                NaN
# 4                       NaN                                                NaN
# 5                       Key                             Statistical robustness
# 6                  CV <= 5%                  Estimates are considered precise
# 7        CV > 5% and <= 10%        Estimates are considered reasonably precise
# 8       CV > 10% and <= 20%                Estimates are considered acceptable
# 9              x = CV > 20%  Estimates are considered unreliable for practi...
# 10          .. = disclosive                                                NaN
# 11       : = not applicable                                                NaN
# 12   - = nil or negligible                                                 NaN
# 13                      NaN                                                NaN
# 14                      NaN                                                NaN
# 15                      NaN                                                NaN
# 16                      NaN                                                NaN
# 17                      NaN                                                NaN
# 18                      NaN                                                NaN
# 19                      NaN                                                NaN
# 20                      NaN                                                NaN
# 21                      NaN                                                NaN
# 22                      NaN                                                NaN
# 23                      NaN                                                NaN
# 24                      NaN                                                NaN
# 25                      NaN                                                NaN
# 26                      NaN                                                NaN
# 27                      NaN                                                NaN
# 28                      NaN                                                NaN
# 29                      NaN                                                NaN
# ..                      ...                                                ...
# 411                     NaN                                                NaN
# 412                     NaN                                                NaN
# 413                     NaN                                                NaN
# 414                     NaN                                                NaN
# 415                     NaN                                                NaN
# 416                     NaN                                                NaN
# 417                     NaN                                                NaN
# 418                     NaN                                                NaN
# 419                     NaN                                                NaN
# 420                     NaN                                                NaN
# 421                     NaN                                                NaN
# 422                     NaN                                                NaN
# 423                     NaN                                                NaN
# 424                     NaN                                                NaN
# 425                     NaN                                                NaN
# 426                     NaN                                                NaN
# 427                     NaN                                                NaN
# 428                     NaN                                                NaN
# 429                     NaN                                                NaN
# 430                     NaN                                                NaN
# 431                     NaN                                                NaN
# 432                     NaN                                                NaN
# 433                     NaN                                                NaN
# 434                     NaN                                                NaN
# 435                     NaN                                                NaN
# 436                     NaN                                                NaN
# 437                     NaN                                                NaN
# 438                     NaN                                                NaN
# 439                     NaN                                                NaN
# 440                     NaN                                                NaN
#
# [441 rows x 20 columns]

# %%
tf = NamedTemporaryFile("w+b", suffix=".xls")
tf.write(z)
tableset = xypath.loader.table_set(tf.name, extension='xls')

# %%
list(k.values())[0].columns
# Out:
# Index(['Table 7.1a   Weekly pay - Gross (£) - For part-time employee jobsa: United Kingdom, 2016',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19'],
#       dtype='object')

# %%
# Simply do everything all at once
import zipfile, io, re, os
from tempfile import NamedTemporaryFile

dirname = "table7zips"
dfiles = os.listdir(dirname)
dfiles.sort(reverse=True)
for dfile in dfiles:
    zfile = os.path.join(dirname, dfile)
    print("opening", zfile)
    zdir = zipfile.ZipFile(zfile)
    xlsfilenames = zdir.namelist()
    for xlsfilename in xlsfilenames:
        z = zdir.read(xlsfilename)
        print(" zfile", xlsfilename, len(z))
        tf = NamedTemporaryFile("w+b", suffix=".xls")
        tf.write(z)
        k = pd.read_excel(tf.name, sheetname=None)
        print(k.keys())
        len(k["All"].columns)
# Out:
# opening table7zips/2016-table72016provisional.zip
#  zfile PROV - Work Geography Table 7.1a   Weekly pay - Gross 2016.xls 893440
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile PROV - Work Geography Table 7.1b   Weekly pay - Gross 2016 CV.xls 915968
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile PROV - Work Geography Table 7.2a   Weekly pay - Excluding overtime 2016.xls 894976
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile PROV - Work Geography Table 7.2b   Weekly pay - Excluding overtime 2016 CV.xls 917504
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile PROV - Work Geography Table 7.3a   Basic Pay - Including other pay 2016.xls 896512
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile PROV - Work Geography Table 7.3b   Basic Pay - Including other pay 2016 CV.xls 917504
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile PROV - Work Geography Table 7.4a   Overtime pay 2016.xls 1052160
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile PROV - Work Geography Table 7.4b   Overtime pay 2016 CV.xls 991232
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile PROV - Work Geography Table 7
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.3b   Weekly pay - Basic 2000 CV.xls 824320
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.4a   Overtime pay 2000.xls 1015296
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.4b   Overtime pay 2000 CV.xls 830976
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.5a   Hourly pay - Gross 2000.xls 763392
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.5b   Hourly pay - Gross 2000 CV.xls 824320
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.6a   Hourly pay - Excluding overtime 2000.xls 763904
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.6b   Hourly pay - Excluding overtime 2000 CV.xls 824320
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.7a   Annual pay - Gross 2000.xls 838656
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.7b   Annual pay - Gross 2000 CV.xls 824320
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.9a   Hours worked - Total 2000.xls 753664
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.9b   Hours worked - Total 2000 CV.xls 824320
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.10a   Hours worked - Basic 2000.xls 752640
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.10b   Hours worked - Basic 2000 CV.xls 824320
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.11a   Hours worked - Overtime 2000.xls 1019904
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
# opening table7zips/1999-1999-table-7.zip
#  zfile Work Geography Table 7.1a   Weekly pay - Gross 1999.xls 798208
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.1b   Weekly pay - Gross 1999 CV.xls 822272
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.2a   Weekly pay - Excluding overtime 1999.xls 801792
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.2b   Weekly pay - Excluding overtime 1999 CV.xls 822272
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.3a   Weekly pay - Basic 1999.xls 801280
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.3b   Weekly pay - Basic 1999 CV.xls 822272
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.4a   Overtime pay 1999.xls 1007104
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.4b   Overtime pay 1999 CV.xls 826368
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.5a   Hourly pay - Gross 1999.xls 760320
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.5b   Hourly pay - Gross 1999 CV.xls 822784
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.6a   Hourly pay - Excluding overtime 1999.xls 761856
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.6b   Hourly pay - Excluding overtime 1999 CV.xls 822272
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.7a   Annual pay - Gross 1999.xls 903168
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.7b   Annual pay - Gross 1999 CV.xls 822272
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.9a   Hours worked - Total 1999.xls 751616
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.9b   Hours worked - Total 1999 CV.xls 822272
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.10a   Hours worked - Basic 1999.xls 751616
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.10b   Hours worked - Basic 1999 CV.xls 822272
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.11a   Hours worked - Overtime 1999.xls 1003008
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.11b   Hours worked - Overtime 1999 CV.xls 826368
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
# opening table7zips/1998-1998-table-7.zip
#  zfile Work Geography Table 7.1b   Weekly pay - Gross 1998 CV.xls 821760
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.2a   Weekly pay - Excluding overtime 1998.xls 799744
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.2b   Weekly pay - Excluding overtime 1998 CV.xls 821760
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.3a   Weekly pay - Basic 1998.xls 799232
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.3b   Weekly pay - Basic 1998 CV.xls 821760
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.4a   Overtime pay 1998.xls 1004032
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.4b   Overtime pay 1998 CV.xls 826368
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.5a   Hourly pay - Gross 1998.xls 761344
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.5b   Hourly pay - Gross 1998 CV.xls 821760
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.6a   Hourly pay - Excluding overtime 1998.xls 762880
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.6b   Hourly pay - Excluding overtime 1998 CV.xls 821760
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.9a   Hours worked - Total 1998.xls 751104
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.9b   Hours worked - Total 1998 CV.xls 821760
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.10a   Hours worked - Basic 1998.xls 749568
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.10b   Hours worked - Basic 1998 CV.xls 821760
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.11a   Hours worked - Overtime 1998.xls 999424
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.11b   Hours worked - Overtime 1998 CV.xls 826368
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.1a   Weekly pay - Gross 1998.xls 798720
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
# opening table7zips/1997-1997-table-7.zip
#  zfile Work Geography Table 7.3a   Weekly pay - Basic 1997.xls 896512
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.3b   Weekly pay - Basic 1997 CV.xls 832512
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.4a   Overtime pay 1997.xls 1036800
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.4b   Overtime pay 1997 CV.xls 838144
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.5a   Hourly pay - Gross 1997.xls 865792
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.5b   Hourly pay - Gross 1997 CV.xls 832512
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.6a   Hourly pay - Excluding overtime 1997.xls 868864
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.6b   Hourly pay - Excluding overtime 1997 CV.xls 832512
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.9a   Hours worked - Total 1997.xls 849408
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.9b   Hours worked - Total 1997 CV.xls 832512
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.10a   Hours worked - Basic 1997.xls 848384
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.10b   Hours worked - Basic 1997 CV.xls 832512
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.11a   Hours worked - Overtime 1997.xls 1033216
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.11b   Hours worked - Overtime 1997 CV.xls 838656
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.1a   Weekly pay - Gross 1997.xls 891904
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.1b   Weekly pay - Gross 1997 CV.xls 832512
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.2a   Weekly pay - Excluding overtime 1997.xls 895488
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])
#  zfile Work Geography Table 7.2b   Weekly pay - Excluding overtime 1997 CV.xls 832512
# dict_keys(['Part-Time', 'Female', 'All', 'Male', 'Female Full-Time', 'Male Full-Time', 'Male Part-Time', 'Female Part-Time', 'Notes', 'Full-Time'])

# %%
len(k["All"].columns)
# Out:
# 20

# %%
import resource
resource.getrusage(resource.RUSAGE_SELF)
# Out:
# resource.struct_rusage(ru_utime=160.204, ru_stime=1.44, ru_maxrss=127964, ru_ixrss=0, ru_idrss=0, ru_isrss=0, ru_minflt=158005, ru_majflt=102, ru_nswap=0, ru_inblock=149616, ru_oublock=5192, ru_msgsnd=0, ru_msgrcv=0, ru_nsignals=0, ru_nvcsw=70778, ru_nivcsw=27704)
