# %%
import urllib.request

# This is the front page for table7
iurl = "https://www.ons.gov.uk/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7"
req = urllib.request.Request(iurl, headers={'User-Agent' : "Magic Browser"}) 
ipage = urllib.request.urlopen(req).read()

# %%
ipage
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]><html class="no-js lt-ie8 lt-ie7" lang="en"><![endif]-->\n<!--[if IE 7]><html class="no-js lt-ie8 ie7"  lang="en"><![endif]-->\n<!--[if IE 8]><html class="ie8" lang="en"><![endif]-->\n<!--[if gt IE 8]><!--><!-->\n<html lang="en">\n\t<!--<![endif]-->\n<head>\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/>\n<title>\nPlace of Work by Local Authority - ASHE: Table 7\n- Office for National Statistics</title>\n<meta charset="utf-8"/>\n<meta content="width=device-width,initial-scale=1.0,user-scalable=1" name="viewport">\n<meta content="on" http-equiv="cleartype"/>\n<meta name="format-detection" content="telephone=no">\n<meta name="theme-color" content="#58595B">\n<meta name="apple-mobile-web-app-status-bar-style" content="#58595B">\n<!--[if IE]><![endif]-->\n<!--[if lte IE 8]>\n\t\t<link rel="stylesheet" href="/assets/css/old-ie.css"/>\n\t\t<![endif]-->\n<!--[if IE 9]>\n              <link rel="stylesheet" type="text/css" href="/assets/css/ie-9.css">\n        <![endif]-->\n<!--[if gt IE 9]><!-->\n<link rel="stylesheet" type="text/css" href="/assets/css/main.css">\n<![endif]-->\n</head>\n<body class="dataset_landing_page">\n<header>\n<a class="skiplink" href="#main" tabindex="0">\nSkip to main content\n</a>\n<div id="pagePath" class="hide">/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7</div>\n<div class="beta-banner">\n<div class="wrapper">\n<p>We are improving our online services and you can help by sharing your needs and opinions in our <a href="https://www.surveymonkey.co.uk/r/8CPWTXQ">short survey</a></p>\n</div>\n</div>\n<div class="wrapper">\n<div class="header col-wrap">\n<div class="col col--lg-one-third col--md-one-third">\n<a href="/">\n<img class="main-logo" src="/assets/img/ons-logo.svg" alt="Office for National Statistics">\n</a>\n</div>\n<div class="col col--lg-two-thirds col--md-two-thirds hide--sm print--hide language--js__container">\n<dl class="language js--hide">\n<dt class="language__title">Language:</dt>\n<dd class="language__item">\n<a href="\n\n\n\n    //cy.ons.gov.uk/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7\n" class="language__link icon--hide">Cymraeg (CY)</a>\n</dd>\n</dl>\n<form class="language language--js js--show">\n<label class="language--js__label" for="lang">Language:</label>\n<select class="language--js__select" id="lang" name="lang">\n<option value="english" data-url="\n\n    //www.www.ons.gov.uk/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7\n\n\n" selected="selected">English (EN)</option>\n<option value="welsh" data-url="\n\n\n\n    //cy.ons.gov.uk/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7\n">Cymraeg (CY)</option>\n</select>\n</form>\n</div>\n<div class="secondary-nav col col--lg-two-thirds col--md-two-thirds print--hide">\n<ul class="secondary-nav__list js-nav-clone__list">\n<li class="secondary-nav__item">\n<a class="secondary-nav__link  js-nav-clone__link" href="/releasecalendar">Release calendar</a>\n</li>\n<li class="secondary-nav__item">\n<a class="secondary-nav__link  js-nav-clone__link" href="/methodology">Methodology</a>\n</li>\n<li class="secondary-nav__item">\n<a class="secondary-nav__link  js-nav-clone__link" href="/news">Media</a>\n</li>\n<li class="secondary-nav__item">\n<a class="secondary-nav__link  js-nav-clone__link" href="/aboutus">About</a>\n</li>\n</ul>\n</div>\n</div>\n</div>\n<div class="primary-nav print--hide">\n<nav>\n<ul class="nav--controls">\n<li class="nav--controls__item">\n<a href="#nav-primary" id="menu-toggle" aria-controls="nav-primary" class="nav--controls__menu">\n<span class="nav--controls__text">Menu</span>\n</a>\n</li>\n<li class="nav--controls__item ">\n<a href="#nav-search" id="search-toggle" aria-controls="nav-search" class="nav--controls__search ...

# %%
import re, urllib.parse, os

# find all the links to the zip files on this index page
zyears = [urllib.parse.urljoin(iurl, z)  for z in re.findall('<a href="([^"]*?\.zip)"', str(ipage))]

dirname = "table7zips"
if not os.path.exists(dirname):
    os.mkdir(dirname)

    
zyears
# Out:
# ['https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2016/table72016provisional.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2015/table72015revised.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2014revised/rft-7(1).zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2013revised/2013-revised-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2012revised/2012-revised-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2011revisedbasedonsoc2010/2011-revised-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2011/2011provisionaltable7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2010revised/2010-revised-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2009/2009-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2008/2008-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2007/2007-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2006consistentw_007methodology/2006-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2006consistentw_005methodology/2006-table-7 (1).zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2005/2005-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2004/2004-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2003/2003-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2002/2002-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2001/2001-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2000/2000-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/1999/1999-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/1998/1998-table-7.zip',
#  'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/1997/1997-table-7.zip']

# %%
# copy and download each of these zip files
for zurl in zyears:
    zfilename = "-".join(zurl.split("/")[-2:])
    zurl = zurl.replace(" ", "%20")   # spaces in the url get escaped in the browser
    req = urllib.request.Request(zurl, headers={'User-Agent' : "Magic Browser"}) 
    zcon = urllib.request.urlopen(req)
    #zcon.headers.items()
    fout = open(os.path.join(dirname, zfilename), "wb")
    zbytes = zcon.read()
    fout.write(zbytes)
    fout.close()
    print(zfilename, len(zbytes), "bytes")
# Out:
# 2016-table72016provisional.zip 6176784 bytes
# 2015-table72015revised.zip 6160666 bytes
# 2014revised-rft-7(1).zip 6154566 bytes
# 2013revised-2013-revised-table-7.zip 6128869 bytes
# 2012revised-2012-revised-table-7.zip 6252178 bytes
# 2011revisedbasedonsoc2010-2011-revised-table-7.zip 6306086 bytes
# 2011-2011provisionaltable7.zip 6788132 bytes
# 2010revised-2010-revised-table-7.zip 6795349 bytes
# 2009-2009-table-7.zip 6299557 bytes
# 2008-2008-table-7.zip 6460891 bytes
# 2007-2007-table-7.zip 6274867 bytes
# 2006consistentw_007methodology-2006-table-7.zip 6386219 bytes
# 2006consistentw_005methodology-2006-table-7 (1).zip 6255157 bytes
# 2005-2005-table-7.zip 6294121 bytes
# 2004-2004-table-7.zip 6461641 bytes
# 2003-2003-table-7.zip 5896387 bytes
# 2002-2002-table-7.zip 5827546 bytes
# 2001-2001-table-7.zip 5263242 bytes
# 2000-2000-table-7.zip 5285670 bytes
# 1999-1999-table-7.zip 5279918 bytes
# 1998-1998-table-7.zip 4733767 bytes
# 1997-1997-table-7.zip 4941445 bytes

# %%
zurl
# Out:
# 'https://www.ons.gov.uk/file?uri=/employmentandlabourmarket/peopleinwork/earningsandworkinghours/datasets/placeofworkbylocalauthorityashetable7/2006consistentw_005methodology/2006-table-7 (1).zip'
