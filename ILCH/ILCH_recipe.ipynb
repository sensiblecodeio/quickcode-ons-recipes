# %% [markdown]
# # ILCH Databaker Recipes
#
# The purpose of this recipe is to create 4 datasets. One growth and one level datasets from the ILCH SA (Seasonally adjusted) spreadsheet, and the same for the NSA (not seasonally adjusted) spreadsheet.
#
# This notebooks contains the following sections
#
# 1.) Introduction, selecting filenames & shared functions
#
# 2.) The recipe code
#
# 3.) Loading and running the NSA recipe
#
# 4.) Loading and running the SA recipe

# %%
from databaker.framework import *

# %%
# FILENAMES - this is the ONLY bit that should need to change
sa_inputfile = "ilchtablestemplatesa.xls"
nsa_inputfile = "ilchtablestemplatensa.xls"

# %%
# Shared functions

# Get the growth period
def get_growthPeriod(tab):
    tab_title = tab.excel_ref('A1')
    
    if tab_title.filter(contains_string("year on year")):
        gp = "Annual"
    elif tab_title.filter(contains_string("quarter on quarter")):
        gp = "Quarterly"
    elif tab_title.filter(contains_string("growth rates")):
        gp = "Annual"
    return gp


# Get the measure type
def get_measureType(tab):
    tab_title = tab.excel_ref('A1')
                       
    if tab_title.filter(contains_string("year on year")):
        mt = "Percent"
    elif tab_title.filter(contains_string("quarter on quarter")):
        mt = "Percent"
    elif tab_title.filter(contains_string("growth rates")):
        mt = "Percent"
    else:
        mt = "Index"
    return mt

# %% [markdown]
# ## The Recipe Code
#
# There are 2 blocks. One defines a function for the "Growth" recipe. The other for the "Level" recipe.

# %%
def growth_recipe(saOrNsa):
    
    conversionsegments = []

    for tab in tabs_growth:

        # Set anchor one to the left of cell with "Agriculture" 
        anchor = tab.filter(contains_string("eriod")).assert_one()

        # set up a waffle
        datarows = anchor.fill(DOWN).is_not_blank()
        datacols = anchor.shift(DOWN).fill(RIGHT).is_not_blank()
        obs = datarows.waffle(datacols).is_not_blank()

        # set the growth period & measuretype
        gp = get_growthPeriod(tab)
        mt = get_measureType(tab)

        dimensions = [
                HDimConst(MEASURETYPE, mt),
                HDim(datarows, TIME, DIRECTLY, LEFT),
                HDim(datacols.parent(), "Costs", DIRECTLY, ABOVE),
                HDim(anchor.fill(RIGHT).parent(), "SIC", CLOSEST, LEFT),
                HDimConst("Growth Period", gp),
                HDimConst("SA / NSA", saOrNsa)
                     ]

        # TIME has wierd data markings, get them out
        time = dimensions[1]
        assert time.name == 'TIME', "Time needs to be dimension 0"
        for val in time.hbagset:
            if '(r)' in val.value or ('p') in val.value:
                time.cellvalueoverride[val.value] = val.value[:6]

        conversionsegment = ConversionSegment(tab, dimensions, obs)
        conversionsegments.append(conversionsegment)
    
    return conversionsegments

# %%
def level_recipe(saOrNsa):
    
    conversionsegments = []

    for tab in tabs_level:

        # Set anchor one to the left of cell with "Agriculture" 
        anchor = tab.filter(contains_string("eriod")).assert_one()

        # set up a waffle
        datarows = anchor.fill(DOWN).is_not_blank()
        datacols = anchor.shift(DOWN).fill(RIGHT).is_not_blank()
        obs = datarows.waffle(datacols).is_not_blank()
        
        # set the measuretype
        mt = get_measureType(tab)

        dimensions = [
                HDim(datarows, TIME, DIRECTLY, LEFT),
                HDim(datacols.parent(), "Costs", DIRECTLY, ABOVE),
                HDim(anchor.fill(RIGHT).parent(), "SIC", CLOSEST, LEFT),
                HDimConst(MEASURETYPE, mt),
                HDimConst("SA / NSA", saOrNsa)
                     ]

        # TIME has wierd data markings, get them out
        time = dimensions[0]
        assert time.name == 'TIME', "Time needs to be dimension 0"
        for val in time.hbagset:
            if '(r)' in val.value or ('p') in val.value:
                time.cellvalueoverride[val.value] = val.value[:6]

        conversionsegment = ConversionSegment(tab, dimensions, obs)
        conversionsegments.append(conversionsegment)
    
    return conversionsegments

# %% [markdown]
# ## Loading and Running the NSA Recipes

# %%
tabs = loadxlstabs(nsa_inputfile)
# Out:
# Loading ilchtablestemplatensa.xls which has size 289792 bytes
# Table names: ['INTRODUCTION', 'DEFINITIONS', '1. Industry level', '2. Sector level', '3. Industry growth rates', '4. Sector growth Rates']

# %%
# get the growth and level tabs
tabs_growth = [x for x in tabs if 'growth' in x.name]
tabs_level = [x for x in tabs if 'level' in x.name]

# Sanity check
assert len(tabs_growth) == 2, "We expect the NSA file to have 2 tabs with the word 'growth' in them"
assert len(tabs_level) == 2, "We expect the NSA file require 2 tabs with the word 'level' in them"

# %%
# Growth, NSA
outputfile = 'Output-NSA-growth-' + nsa_inputfile[:-4] + '.csv'
writetechnicalCSV(outputfile, growth_recipe("Not seasonally adjusted"))

# LEvel SA
outputfile = 'Output-NSA-level-' + nsa_inputfile[:-4] + '.csv'
writetechnicalCSV(outputfile, level_recipe("Not seasonally adjusted"))
# Out:
# writing 2 conversion segments into /home/goatchurch/sensiblecode/quickcode-ons-recipes/ILCH/Output-NSA-growth-ilchtablestemplatensa.csv
# conversionwrite segment size 5952 table '3. Industry growth rates; TIMEUNIT='Quarter'
# conversionwrite segment size 2232 table '4. Sector growth Rates; TIMEUNIT='Quarter'
# writing 2 conversion segments into /home/goatchurch/sensiblecode/quickcode-ons-recipes/ILCH/Output-NSA-level-ilchtablestemplatensa.csv
# conversionwrite segment size 6336 table '1. Industry level; TIMEUNIT='Quarter'
# conversionwrite segment size 2376 table '2. Sector level; TIMEUNIT='Quarter'

# %% [markdown]
# ## Loading and Running the SA Recipes

# %%
tabs = loadxlstabs(sa_inputfile)
# Out:
# Loading ilchtablestemplatesa.xls which has size 407552 bytes
# Table names: ['INTRODUCTION', 'DEFINITIONS', '1. Industry level SA', '2. Sector level SA', '3. Industry annual growth SA', '4. Sector annual growth SA', '5. Industry quarterly growth SA', '6. Sector quarterly growth SA']

# %%
# get the growth and level tabs
tabs_growth = [x for x in tabs if 'growth' in x.name]
tabs_level = [x for x in tabs if 'level' in x.name]

# Sanity check
assert len(tabs_growth) == 4, "We expect the SA file to have 4 tabs with the word 'growth' in them"
assert len(tabs_level) == 2, "We expect the SA file require 2 tabs with the word 'level' in them"

# %%
# Growth, SA
outputfile = 'Output-SA-growth-' + sa_inputfile[:-4] + '.csv'
writetechnicalCSV(outputfile, growth_recipe("Seasonally Adjusted"))   # 'A' to match previous months

# LEvel SA
outputfile = 'Output-SA-level-' + sa_inputfile[:-4] + '.csv'
writetechnicalCSV(outputfile, level_recipe("Seasonally adjusted"))
# Out:
# writing 4 conversion segments into /home/goatchurch/sensiblecode/quickcode-ons-recipes/ILCH/Output-SA-growth-ilchtablestemplatesa.csv
# conversionwrite segment size 5952 table '3. Industry annual growth SA; TIMEUNIT='Quarter'
# conversionwrite segment size 2232 table '4. Sector annual growth SA; TIMEUNIT='Quarter'
# conversionwrite segment size 6240 table '5. Industry quarterly growth SA; TIMEUNIT='Quarter'
# conversionwrite segment size 2340 table '6. Sector quarterly growth SA; TIMEUNIT='Quarter'
# writing 2 conversion segments into /home/goatchurch/sensiblecode/quickcode-ons-recipes/ILCH/Output-SA-level-ilchtablestemplatesa.csv
# conversionwrite segment size 6336 table '1. Industry level SA; TIMEUNIT='Quarter'
# conversionwrite segment size 2376 table '2. Sector level SA; TIMEUNIT='Quarter'

# %%
topandas(level_recipe("Seasonally adjusted")[0])
# Out:
#                                                     SIC     -9  \
# 0             ILCH_A\nAgriculture, Forestry and Fishing   92.8
# 1             ILCH_A\nAgriculture, Forestry and Fishing   92.3
# 2             ILCH_A\nAgriculture, Forestry and Fishing   94.1
# 3             ILCH_A\nAgriculture, Forestry and Fishing   92.7
# 4                          ILCH_B\nMining and Quarrying   90.8
# 5                          ILCH_B\nMining and Quarrying   91.3
# 6                          ILCH_B\nMining and Quarrying   82.6
# 7                          ILCH_B\nMining and Quarrying   96.4
# 8     ILCH_C1\nManufacturing - Food Products, Bevera...   94.0
# 9     ILCH_C1\nManufacturing - Food Products, Bevera...   93.8
# 10    ILCH_C1\nManufacturing - Food Products, Bevera...   94.0
# 11    ILCH_C1\nManufacturing - Food Products, Bevera...   94.7
# 12    ILCH_C2\nManufacturing - Textiles, Leather and...   97.8
# 13    ILCH_C2\nManufacturing - Textiles, Leather and...  100.4
# 14    ILCH_C2\nManufacturing - Textiles, Leather and...  102.6
# 15    ILCH_C2\nManufacturing - Textiles, Leather and...   97.9
# 16    ILCH_C3\nManufacturing - Chemicals and Man-mad...   94.2
# 17    ILCH_C3\nManufacturing - Chemicals and Man-mad...   94.1
# 18    ILCH_C3\nManufacturing - Chemicals and Man-mad...   91.4
# 19    ILCH_C3\nManufacturing - Chemicals and Man-mad...   99.3
# 20    ILCH_C4\nManufacturing - Basic Metals and Meta...   98.7
# 21    ILCH_C4\nManufacturing - Basic Metals and Meta...   98.6
# 22    ILCH_C4\nManufacturing - Basic Metals and Meta...   99.2
# 23    ILCH_C4\nManufacturing - Basic Metals and Meta...  100.8
# 24    ILCH_C5\nManufacturing - Engineering and Allie...   95.7
# 25    ILCH_C5\nManufacturing - Engineering and Allie...   95.6
# 26    ILCH_C5\nManufacturing - Engineering and Allie...   93.2
# 27    ILCH_C5\nManufacturing - Engineering and Allie...   98.7
# 28                         ILCH_C6\nOther Manufacturing   98.4
# 29                         ILCH_C6\nOther Manufacturing   99.1
# ...                                                 ...    ...
# 6306                     ILCH_L\nReal Estate Activities  179.2
# 6307                     ILCH_L\nReal Estate Activities  156.1
# 6308  ILCH_M\nProfessional, Scientific & Technical A...  160.7
# 6309  ILCH_M\nProfessional, Scientific & Technical A...  157.5
# 6310  ILCH_M\nProfessional, Scientific & Technical A...  190.1
# 6311  ILCH_M\nProfessional, Scientific & Technical A...  154.9
# 6312  ILCH_N\nAdministrative and Support Service Act...  162.2
# 6313  ILCH_N\nAdministrative and Support Service Act...  161.0
# 6314  ILCH_N\nAdministrative and Support Service Act...  181.4
# 6315  ILCH_N\nAdministrative and Support Service Act...  160.5
# 6316                      ILCH_O\nPublic Administration  150.1
# 6317                      ILCH_O\nPublic Administration  148.9
# 6318                      ILCH_O\nPublic Administration  160.5
# 6319                      ILCH_O\nPublic Administration  150.4
# 6320                                  ILCH_P\nEducation  159.7
# 6321                                  ILCH_P\nEducation  153.3
# 6322                                  ILCH_P\nEducation  197.2
# 6323                                  ILCH_P\nEducation  160.2
# 6324                     ILCH_Q\nHealth and Social Work  165.1
# 6325                     ILCH_Q\nHealth and Social Work  162.0
# 6326                     ILCH_Q\nHealth and Social Work  195.5
# 6327                     ILCH_Q\nHealth and Social Work  166.1
# 6328         ILCH_R\nArts, Entertainment and Recreation  159.8
# 6329         ILCH_R\nArts, Entertainment and Recreation  159.3
# 6330         ILCH_R\nArts, Entertainment and Recreation  182.2
# 6331         ILCH_R\nArts, Entertainment and Recreation  159.3
# 6332                   ILCH_S\nOther Service Activities  170.7
# 6333                   ILCH_S\nOther Service Activities  165.4
# 6334                   ILCH_S\nOther Service Activities  210.7
# 6335                   ILCH_S\nOther Service Activities  169.0
#
#                                                   Costs     -6  \
# 0                                 Labour Costs per Hour  Index
# 1                                   Wage Costs per Hour  Index
# 2                                  Other Costs per Hour  Index
# 3     Labour Costs per Hour Excluding Bonuses and Ar...  Index
# 4                                 Labour Costs per Hour  Index
# 5                                   Wage Costs per Hour  Index
# 6                                  Other Costs per Hour  Index
# 7     Labour Costs per Hour Excluding Bonuses and Ar...  Index
# 8                                 Labour Costs per Hour  Index
# 9                                   Wage Costs per Hour  Index
# 10                                 Other Costs per Hour  Index
# 11    Labour Costs per Hour Excluding Bonuses and Ar...  Index
# 12                                Labour Costs per Hour  Index
# 13                                  Wage Costs per Hour  Index
# 14                                 Other Costs per Hour  Index
# 15    Labour Costs per Hour Excluding Bonuses and Ar...  Index
# 16                                Labour Costs per Hour  Index
# 17                                  Wage Costs per Hour  Index
# 18                                 Other Costs per Hour  Index
# 19    Labour Costs per Hour Excluding Bonuses and Ar...  Index
# 20                                Labour Costs per Hour  Index
# 21                                  Wage Costs per Hour  Index
# 22                                 Other Costs per Hour  Index
# 23    Labour Costs per Hour Excluding Bonuses and Ar...  Index
# 24                                Labour Costs per Hour  Index
# 25                                  Wage Costs per Hour  Index
# 26                                 Other Costs per Hour  Index
# 27    Labour Costs per Hour Excluding Bonuses and Ar...  Index
# 28                                Labour Costs per Hour  Index
# 29                                  Wage Costs per Hour  Index
# ...                                                 ...    ...
# 6306                               Other Costs per Hour  Index
# 6307  Labour Costs per Hour Excluding Bonuses and Ar...  Index
# 6308                              Labour Costs per Hour  Index
# 6309                                Wage Costs per Hour  Index
# 6310                               Other Costs per Hour  Index
# 6311  Labour Costs per Hour Excluding Bonuses and Ar...  Index
# 6312                              Labour Costs per Hour  Index
# 6313                                Wage Costs per Hour  Index
# 6314                               Other Costs per Hour  Index
# 6315  Labour Costs per Hour Excluding Bonuses and Ar...  Index
# 6316                              Labour Costs per Hour  Index
# 6317                                Wage Costs per Hour  Index
# 6318                               Other Costs per Hour  Index
# 6319  Labour Costs per Hour Excluding Bonuses and Ar...  Index
# 6320                              Labour Costs per Hour  Index
# 6321                                Wage Costs per Hour  Index
# 6322                               Other Costs per Hour  Index
# 6323  Labour Costs per Hour Excluding Bonuses and Ar...  Index
# 6324                              Labour Costs per Hour  Index
# 6325                                Wage Costs per Hour  Index
# 6326                               Other Costs per Hour  Index
# 6327  Labour Costs per Hour Excluding Bonuses and Ar...  Index
# 6328                              Labour Costs per Hour  Index
# 6329                                Wage Costs per Hour  Index
# 6330                               Other Costs per Hour  Index
# 6331  Labour Costs per Hour Excluding Bonuses and Ar...  Index
# 6332                              Labour Costs per Hour  Index
# 6333                                Wage Costs per Hour  Index
# 6334                               Other Costs per Hour  Index
# 6335  Labour Costs per Hour Excluding Bonuses and Ar...  Index
#
#                  SA / NSA      -2
# 0     Seasonally adjusted  2000Q1
# 1     Seasonally adjusted  2000Q1
# 2     Seasonally adjusted  2000Q1
# 3     Seasonally adjusted  2000Q1
# 4     Seasonally adjusted  2000Q1
# 5     Seasonally adjusted  2000Q1
# 6     Seasonally adjusted  2000Q1
# 7     Seasonally adjusted  2000Q1
# 8     Seasonally adjusted  2000Q1
# 9     Seasonally adjusted  2000Q1
# 10    Seasonally adjusted  2000Q1
# 11    Seasonally adjusted  2000Q1
# 12    Seasonally adjusted  2000Q1
# 13    Seasonally adjusted  2000Q1
# 14    Seasonally adjusted  2000Q1
# 15    Seasonally adjusted  2000Q1
# 16    Seasonally adjusted  2000Q1
# 17    Seasonally adjusted  2000Q1
# 18    Seasonally adjusted  2000Q1
# 19    Seasonally adjusted  2000Q1
# 20    Seasonally adjusted  2000Q1
# 21    Seasonally adjusted  2000Q1
# 22    Seasonally adjusted  2000Q1
# 23    Seasonally adjusted  2000Q1
# 24    Seasonally adjusted  2000Q1
# 25    Seasonally adjusted  2000Q1
# 26    Seasonally adjusted  2000Q1
# 27    Seasonally adjusted  2000Q1
# 28    Seasonally adjusted  2000Q1
# 29    Seasonally adjusted  2000Q1
# ...                   ...     ...
# 6306  Seasonally adjusted  2016Q2
# 6307  Seasonally adjusted  2016Q2
# 6308  Seasonally adjusted  2016Q2
# 6309  Seasonally adjusted  2016Q2
# 6310  Seasonally adjusted  2016Q2
# 6311  Seasonally adjusted  2016Q2
# 6312  Seasonally adjusted  2016Q2
# 6313  Seasonally adjusted  2016Q2
# 6314  Seasonally adjusted  2016Q2
# 6315  Seasonally adjusted  2016Q2
# 6316  Seasonally adjusted  2016Q2
# 6317  Seasonally adjusted  2016Q2
# 6318  Seasonally adjusted  2016Q2
# 6319  Seasonally adjusted  2016Q2
# 6320  Seasonally adjusted  2016Q2
# 6321  Seasonally adjusted  2016Q2
# 6322  Seasonally adjusted  2016Q2
# 6323  Seasonally adjusted  2016Q2
# 6324  Seasonally adjusted  2016Q2
# 6325  Seasonally adjusted  2016Q2
# 6326  Seasonally adjusted  2016Q2
# 6327  Seasonally adjusted  2016Q2
# 6328  Seasonally adjusted  2016Q2
# 6329  Seasonally adjusted  2016Q2
# 6330  Seasonally adjusted  2016Q2
# 6331  Seasonally adjusted  2016Q2
# 6332  Seasonally adjusted  2016Q2
# 6333  Seasonally adjusted  2016Q2
# 6334  Seasonally adjusted  2016Q2
# 6335  Seasonally adjusted  2016Q2
#
# [6336 rows x 6 columns]
